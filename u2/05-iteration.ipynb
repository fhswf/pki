# %% [markdown]
# <figure>
#   <IMG SRC="https://raw.githubusercontent.com/fhswf/datasets/refs/heads/main/images/fh-swf-logo.svg" WIDTH=250 ALIGN="right">
# </figure>
#
# # Programmierung für KI
# ### Winterersemester 2026/27
# Prof. Dr. Heiner Giefers

# %% [markdown]
# **Aufgabe 1: Schreiben Sie ein Programm, das wiederholt Zahlen einliest, bis der Benutzer den Befehl `done` eingibt. Sobald `done` eingegeben wurde, geben Sie die Summe, die Anzahl und den Durchschnitt der Zahlen aus. Geben Sie mindestens eine Zahl ein, bevor Sie `done` eingeben. Wenn der Benutzer etwas anderes als eine Zahl eingibt, erkennen Sie seinen Fehler mit `try` und `except` und verlassen die Funktion, indem Sie die Fehlermeldung `Es werden nur Zahlen akzeptiert. Beenden mit 'done'` als Zeichenkette (mit `return`)
# zurückgeben.**
#
# *Erwartete Ausgabe:*
#
#     Bitte eine Zahl eingeben: 2
#     Bitte eine Zahl eingeben: 4
#     Bitte eine Zahl eingeben: 6
#     Bitte eine Zahl eingeben: done
#     Anzahl: 3 Summe: 12.0 Durchschnitt: 4.0

# %%
def durchschnitt():
    anzahl = 0
    summe = 0
    durchschnitt = 0
    # YOUR CODE HERE
    raise NotImplementedError()
    erg = "Anzahl: " + str(anzahl) + " Summe: " + str(summe) + " Durchschnitt: " + str(durchschnitt)
    print(erg)
    return erg

# %%
"""Teste die Funktion durchschnitt auf Gültigkeit."""

def myinput(inputs):
    def foo(a):
        print(a)
        foo.counter += 1
        if foo.counter > len(inputs):
            raise RuntimeError("Nicht genügend inputs")
        return inputs[foo.counter - 1]
    foo.counter = 0
    return foo

from nose.tools import assert_equal

input_old = input
# Erster Testlauf, Abschluss der Eingabe mit "done"
input = myinput(['2','4', '6', 'done'])
s1 = durchschnitt()
# Zweiter Testlauf, Abschluss der Eingabe mit fehlerhaftem Input
input = myinput(['2','4','falsch'])
s2 = durchschnitt()
# Dritter Testlauf, keine Zahl vor "done"
input = myinput(['done'])
s3 = durchschnitt()
input = input_old

assert "Anzahl: 3 Summe: 12.0 Durchschnitt: 4.0" in s1, "Die Ausgabe stimmt nicht"
assert "Es werden nur Zahlen akzeptiert" in s2, "Die Fehlermeldung ist nicht korrekt"
assert "Es muss mindestens eine Zahl eingegeben werden" in s3, "Leere Eingabe wird nicht korrekt behandelt"

# %% [markdown]
# **Aufgabe 2: Schreiben Sie ein weiteres Programm, das eine Liste von Zahlen wie oben abfragt und am Ende sowohl das Maximum als auch das Minimum der Zahlen anstelle des Durchschnitts ausgibt. Geben Sie mindestens eine Zahl ein, bevor Sie `done` eingeben.**

# %%
def minmax():
    anzahl = 0
    minimum = None
    maximum = None
    # YOUR CODE HERE
    raise NotImplementedError()
    erg = "Minimum: " + str(minimum) + " Maximum: " + str(maximum)
    print(erg)
    return erg

# %%
"""Teste die Funktion minmax auf Gültigkeit."""

def myinput(inputs):
    def foo(a):
        print(a)
        foo.counter += 1
        if foo.counter > len(inputs):
            raise RuntimeError("Nicht genügend inputs")
        return inputs[foo.counter - 1]
    foo.counter = 0
    return foo

from nose.tools import assert_equal

input_old = input
input = myinput(['2','4','1','done'])
s1 = minmax()
input = myinput(['2','4','test'])
s2 = minmax()
input = myinput(['done'])
s3 = minmax()
input = input_old

assert "Minimum: 1.0 Maximum: 4.0" in s1, "Die Ausgabe stimmt nicht"
assert "Es werden nur Zahlen akzeptiert" in s2, "Die Fehlermeldung ist nicht korrekt"
assert "Es muss mindestens eine Zahl eingegeben werden" in s3, "Leere Eingabe wird nicht korrekt behandelt"
